# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathi32/PRACT1/blob/main/exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# exp 1 - intro to python
#
# SAKSHI RATHI
#
# 25070123129

# %%
x,y,z="apple","cherry","orange"
print(x,y,z,sep="\n")
# Out:
# apple
# cherry
# orange

# %%
x,y,w,z=2,2.5,"anurag",True
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=10
b=5
print("sum=",a+b)
print("sub=",a-b)
print("mult=",a*b)
print("div=",a/b)
print("exp=",a**b)
# Out:
# sum= 15
# sub= 5
# mult= 50
# div= 2.0
# exp= 100000

# %%
a=int(input("enter a="))
b=int(input("enter b="))
print("sum=",a+b,"\n","sub=",a-b,"\n","mult=",a*b,"\n","div=",a/b,"\n","exp=",a**b,"\n")
# Out:
# enter a=5
# enter b=9
# sum= 14
#  sub= -4
#  mult= 45
#  div= 0.5555555555555556
#  exp= 1953125

# %%
import math
radius = float(input("Enter r:"))
area = math.pi*radius**2
print(area)
# Out:
# Enter r:6
# 113.09733552923255

# %%
import math
math.log10(10)
# Out:
# 1.0

# %%
A=float(input("Enter A:"))
B = float(input("Enter B:"))
if B < A:
    print("B is less than A")
else:
    print("B is GREATER than A")
# Out:
# Enter A:10
# Enter B:5
# B is less than A
